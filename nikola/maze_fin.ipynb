# %%
import maze
# Out:
# Creating necessary folders ...
# ...
# 100%|██████████| 13/13 [00:00<00:00, 13028.90it/s]
# Finished downloading images!

# %%
maze_name = 'probni'
redak = 50
stupac = 50

# %%
koordinate, maze_letters, points = maze.generate_maze(redak, stupac, maze_name)
# Out:
# C:\Users\Nikola\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\Nikola\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\Nikola\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\Nikola\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
# ...

# %%
points
# Out:
# ((45, 0), (6, 33), (0, 32))

# %%
blank_image, _, susjed, matrix = maze.create_maze(maze_letters, redak, stupac, maze_name)

# %%
blank_image
# Out:
# <PIL.Image.Image image mode=RGB size=3500x3500 at 0x22FCD0D9198>

# %%
image1 = maze.copy_image(blank_image)
image1 = maze.label_ends(points[0], points[1], image1)
image1
# Out:
# <PIL.Image.Image image mode=RGB size=3500x3500 at 0x22FBC51A4A8>

# %%
image2 = maze.copy_image(blank_image)
image2 = maze.label_ends(points[0], points[2], image2)
image2
# Out:
# <PIL.Image.Image image mode=RGB size=3500x3500 at 0x22FBC271F28>

# %%
solution = maze.get_solution(koordinate, points[0], points[1])

# %%
image = maze.solve_maze(maze_letters, redak, stupac, solution, maze_name, (points[0], points[1]))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=3500x3500 at 0x22FCD12FF60>

# %%
image.close()

# %%
solution = maze.get_solution(koordinate, points[0], points[2])

# %%
image = maze.solve_maze(maze_letters, redak, stupac, solution, maze_name, (points[0], points[2]))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=3500x3500 at 0x22FCD12B160>

# %%
blank_image.close()
image.close()
image1.close()
image2.close()

# %%
maze_zadano = maze.read_maze('maze2')

# %%
maze_zadano
# Out:
# [['l', 'f', 'k', 'k', 'k', 'g', 'o', 'g', 'f', 'c', 'k', 'k', 'k', 'k', 'm'],
#  ['b', 'h', 'f', 'k', 'g', 'i', 'g', 'j', 'j', 'i', 'k', 'k', 'k', 'k', 'g'],
#  ['i', 'g', 'b', 'g', 'i', 'k', 'e', 'h', 'j', 'o', 'k', 'k', 'k', 'g', 'j'],
#  ['l', 'j', 'n', 'i', 'k', 'c', 'k', 'k', 'h', 'f', 'g', 'f', 'g', 'i', 'h'],
#  ['i', 'd', 'f', 'g', 'f', 'd', 'f', 'c', 'm', 'j', 'b', 'h', 'j', 'f', 'g'],
#  ['f', 'e', 'd', 'n', 'j', 'n', 'j', 'n', 'f', 'h', 'i', 'g', 'i', 'h', 'n'],
#  ['j', 'f', 'h', 'f', 'd', 'f', 'h', 'f', 'e', 'k', 'm', 'i', 'c', 'k', 'g'],
#  ['j', 'j', 'f', 'h', 'j', 'b', 'k', 'd', 'f', 'k', 'g', 'f', 'h', 'o', 'd'],
#  ['b', 'h', 'i', 'g', 'n', 'i', 'g', 'n', 'i', 'g', 'j', 'j', 'f', 'g', 'j'],
#  ['i', 'k', 'm', 'i', 'k', 'k', 'h', 'o', 'k', 'h', 'i', 'h', 'n', 'i', 'h']]

# %%
blank_image, koordinate, susjed, matrix = maze.create_maze(maze_zadano, 10, 15, 'maze2')

# %%
blank_image
# Out:
# <PIL.Image.Image image mode=RGB size=1050x700 at 0x22FCD12F1D0>

# %%
solution = maze.get_solution(koordinate, (0,7), (9,7))

# %%
image = maze.solve_maze(maze_zadano, 10, 15, solution, 'maze2', ((0,7), (9,7)))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=1050x700 at 0x22FCD12E588>

# %%
blank_image.close()
image.close()
